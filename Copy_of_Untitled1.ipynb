# %% [markdown]
# <a href="https://colab.research.google.com/github/moseskhisabarasa1-debug/Mogul-/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="moses"
print("hi"+ name)
# Out:
# himoses

# %%
age=30
if age>35:
  print("age is greater than 35")
else:
    print("age is less than 35")
# Out:
# age is less than 35

# %%
import numpy as np

weight_kg = np.array([67, 76, 80, 100, 56, 87])
height_m = np.array([1.77, 1.87, 1.66, 1.90, 2.00, 1.88])

bmi = weight_kg / (height_m**2)

print("BMI values and categories:")
for i, value in enumerate(bmi):
    if value < 18.5:
        category = "Underweight"
    elif 18.5 <= value < 24.9:
        category = "Normal weight"
    elif 24.9 <= value < 29.9:
        category = "Overweight"
    else:
        category = "Obese"
    print(f"Person {i+1}: BMI = {value:.2f}, Category: {category}")
# Out:
# BMI values and categories:
# Person 1: BMI = 21.39, Category: Normal weight
# Person 2: BMI = 21.73, Category: Normal weight
# Person 3: BMI = 29.03, Category: Overweight
# Person 4: BMI = 27.70, Category: Overweight
# Person 5: BMI = 14.00, Category: Underweight
# Person 6: BMI = 24.62, Category: Normal weight
