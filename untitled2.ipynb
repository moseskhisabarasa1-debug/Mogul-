# %% [markdown]
# <a href="https://colab.research.google.com/github/moseskhisabarasa1-debug/Mogul-/blob/main/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files, drive
drive.mount('/content/drive')
# !ls "/content/drive/My Drive/"
df=pd.read_csv('/content/drive/My Drive/Heart.csv')
df.head()
df.info()
df.describe()
df.isnull().sum()
print("\nAge of the first 5 patients:")
print(df['Age'].iloc[4])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '254 mogul.docx'
# 'AI Hackathon Overall_Plan OUK -BCS_copy.pdf'
#  all.csv
# 'Colab Notebooks'
#  Coma.gdoc
#  FeeStatement-HHR00013022_copy.pdf
# 'GraduationTracker-HHR00013022_copy (1).pdf'
#  GraduationTracker-HHR00013022_copy.pdf
#  Heart.csv
# 'legil doneee.docx'
# 'LEGIT REPORT.docx'
# 'Revised UCI Exams Sitting Arrangement - Sem 1 2025-2026AY_copy.pdf'
# 'TapScanner 08-09-2023-21꞉50 (1).pdf'
#  THE-DATA-PROTECTION-GENERAL-REGULATIONS-2021-1_copy.pdf
#  Transcript-ESN00086024_copy.pdf
#  Transcript-HHR00013022_copy.pdf
# 'User Guide for Investor Portal and Mobile APPs_copy.pdf'
# 'Your paragraph text 1.png'
# 'Your paragraph text 2.png'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
